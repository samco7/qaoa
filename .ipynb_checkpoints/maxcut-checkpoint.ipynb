# %%
#import packages
import numpy as np
from scipy.optimize import minimize
from qaoa import maxcut #this is a .py file with my qaoa code
from qiskit.visualization import plot_histogram
import networkx as nx
from networkx.algorithms.approximation import maxcut as nxmaxcut
from time import time
from matplotlib import pyplot as plt
plt.style.use('seaborn')

# %% [markdown]
# # Weighted Max-Cut

# %% [markdown]
# #### Application: Clustering within Autonomous Sensor Data

# %%
# set up two random distributions with n_points total points and plot
n1 = 6
n2 = 4
n_points = n1 + n2
set1  = np.random.normal(-10, 5, (2, n1))
set2 = np.random.normal(10, 5, (2, n2))
plt.scatter(set1[0, :], set1[1, :])
plt.scatter(set2[0, :], set2[1, :])
plt.axis('equal')
plt.show()

# %%
# create a dictionary mapping points to nodes
combined_set = np.hstack((set1, set2))
ind = np.arange(n_points)
np.random.shuffle(ind)
combined_set = combined_set[:, ind]
nodes_points = dict()
counter = 0
for column in range(combined_set.shape[1]):
    nodes_points[counter] = combined_set[:, column]
    counter += 1
nodes = nodes_points.keys()
plt.scatter(combined_set[0, :], combined_set[1, :], color='teal')
plt.axis('equal')
plt.show()

# %%
# now set up edges with weights corresponding to distances between nodes/points
G = nx.Graph()
for node1 in nodes:
    point1 = nodes_points[node1]
    for node2 in nodes:
        if node2 == node1:
            continue
        point2 = nodes_points[node2]
        weight = np.linalg.norm(point1 - point2)
        G.add_edge(node1, node2, weight=weight)

# draw the graph (note that weight is not reflected here as of now, gets messy)
nx.draw(G)

# %%
# make an instance of the maxcut class
n_layers = n_points #number of layers (scale it up linearly with n_points)
shots = 1024
cut = maxcut(G, n_layers, shots)

# get the expectation function from qaoa.py
start = time()
expectation = cut.get_expectation()

# minimize the expectation by running the circuit
initial_params = .005*np.random.uniform(-1, 1, 2*n_layers)
sol = minimize(expectation, initial_params, method='COBYLA')
result = expectation(sol.x, return_result=True)[1]
counts = result.get_counts()
print(sol)

# get the optimal bitstring we found and print it, along with other stats
true1 = ['0' for x in range(n1)]
true2 = ['1' for x in range(n2)]
true_bitstring = ''.join(np.concatenate((true1, true2))[ind])
found_bitstring = list(counts.keys())[np.argmax(list(counts.values()))]
print('\nTrue Optimal Bitstring: ' + true_bitstring)
print('Found Bitstring: ' + found_bitstring)
print('Simulation Runtime: ' + str(round(time() - start, 4)) + ' seconds')
print('Estimated Device Time: ' + str(round(cut.total_time, 4)) + ' seconds')
# Out:
#      fun: -562.8715865995788
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 218
#   status: 1
#  success: True
#        x: array([-0.02770224, -0.01422055,  0.04186242,  0.00271456,  1.04623614,
#         1.02509384, -0.02415562,  0.01460092,  0.01867688,  0.01316723,
#         0.00117044, -0.00335402,  0.0223102 , -0.01430903,  0.00562274,
#         0.01760621, -0.14107806,  1.16071342,  1.013588  , -0.03951453])
#
# True Optimal Bitstring: 0101001010
# Found Bitstring: 1010110101
# Simulation Runtime: 86.0044 seconds
# Estimated Device Time: 2.8226 seconds

# %%
# plot a histogram of the bitstring counts using our optimized parameters
plot_histogram(counts)
# np.sum(list(counts.values()))

# %%
# convert the result back to points separated by the cut we found above
cluster0, cluster1 = [], []
counter = 0
for char in found_bitstring:
    if int(char) == 0:
        cluster0.append(nodes_points[counter])
    else:
        cluster1.append(nodes_points[counter])
    counter += 1

# plot our points/clusters
cluster0 = np.vstack((cluster0)).T
plt.scatter(cluster0[0, :], cluster0[1, :])
cluster1 = np.vstack((cluster1)).T
plt.scatter(cluster1[0, :], cluster1[1, :])
plt.axis('equal')
plt.show()

# %%
print('True Minimum: ' + str(cut.maxcut_obj(true_bitstring)))
print('Found Minimum: ' + str(cut.maxcut_obj(found_bitstring)))
print('True Optimal Bitstring: ' + str(true_bitstring))
print('Found Optimal Bitstring: ' + str(found_bitstring))
# Out:
# True Minimum: -696.8852031481066
# Found Minimum: -696.8852031481066
# True Optimal Bitstring: 0101001010
# Found Optimal Bitstring: 1010110101

# %%
start = time()
print(nxmaxcut.one_exchange(G, weight='weight'))
classical_time = time() - start
print('Classical Runtime: ' + str(round(classical_time, 4)) + ' seconds')
print('Estimated Device Time: ' + str(round(cut.total_time, 4)) + ' seconds')
# Out:
# (696.8852031481065, ({8, 1, 3, 6}, {0, 2, 4, 5, 7, 9}))
# Classical Runtime: 0.0008 seconds
# Estimated Device Time: 2.8226 seconds
